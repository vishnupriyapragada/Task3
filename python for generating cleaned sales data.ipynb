# %%
import pandas as pd

# %%
# Load the CSV file with semicolon separator
df = pd.read_csv("C:/Users/vpriy/Downloads/sales.csv", sep=';')

# %%
df
# Out:
#        index        Date    Year     Month  Customer Age Customer Gender  \
# 0          0  19/02/2016  2016.0  February          29.0               F
# 1          1  20/02/2016  2016.0  February          29.0               F
# 2          2  27/02/2016  2016.0  February          29.0               F
# 3          3  12/03/2016  2016.0     March          29.0               F
# 4          4  12/03/2016  2016.0     March          29.0               F
# ...      ...         ...     ...       ...           ...             ...
# 34862  34862  07/02/2016  2016.0  February          38.0               M
# 34863  34863  13/03/2015  2015.0     March          38.0               M
# 34864  34864  05/04/2015  2015.0     April          38.0               M
# 34865  34865  30/08/2015  2015.0    August          38.0               M
# 34866  34866         NaN     NaN       NaN           NaN             NaN
#
#              Country           State Product Category     Sub Category  \
# ...

# %%
df.to_csv("cleaned_sales_data.csv", index=False)
